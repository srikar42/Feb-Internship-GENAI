# %% [markdown]
# # Install Library

# %%
# Install LangChain libraries required for prompt templates

# !pip install langchain
# !pip install langchain-core
# Out:
# Collecting langchain
#   Downloading langchain-1.2.15-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-core<2.0.0,>=1.2.10 (from langchain)
#   Downloading langchain_core-1.2.28-py3-none-any.whl.metadata (4.4 kB)
# Collecting langgraph<1.2.0,>=1.1.5 (from langchain)
#   Downloading langgraph-1.1.6-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\admin\anaconda3\lib\site-packages (from langchain) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading langsmith-0.7.29-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\admin\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading langgraph_checkpoint-4.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.9 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading langgraph_prebuilt-1.0.9-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading langgraph_sdk-0.3.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading xxhash-3.6.0-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading ormsgpack-1.12.2-cp313-cp313-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\admin\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading orjson-3.11.8-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\admin\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.24.0)
# Requirement already satisfied: anyio in c:\users\admin\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.10.0)
# Requirement already satisfied: certifi in c:\users\admin\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\admin\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\admin\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\admin\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\admin\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\admin\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\admin\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\admin\anaconda3\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.3.0)
# Downloading langchain-1.2.15-py3-none-any.whl (112 kB)
# Downloading langchain_core-1.2.28-py3-none-any.whl (508 kB)
# Downloading langgraph-1.1.6-py3-none-any.whl (169 kB)
# Downloading langgraph_checkpoint-4.0.1-py3-none-any.whl (50 kB)
# Downloading langgraph_prebuilt-1.0.9-py3-none-any.whl (35 kB)
# Downloading langgraph_sdk-0.3.13-py3-none-any.whl (96 kB)
# Downloading langsmith-0.7.29-py3-none-any.whl (367 kB)
# Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl (187 kB)
# Downloading orjson-3.11.8-cp313-cp313-win_amd64.whl (127 kB)
# Downloading ormsgpack-1.12.2-cp313-cp313-win_amd64.whl (117 kB)
# Downloading xxhash-3.6.0-cp313-cp313-win_amd64.whl (31 kB)
# Installing collected packages: xxhash, uuid-utils, ormsgpack, orjson, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#
#    -------------- -------------------------  4/11 [langsmith]
#    -------------- -------------------------  4/11 [langsmith]
#    -------------- -------------------------  4/11 [langsmith]
#    ------------------ ---------------------  5/11 [langgraph-sdk]
#    --------------------- ------------------  6/11 [langchain-core]
#    --------------------- ------------------  6/11 [langchain-core]
#    --------------------- ------------------  6/11 [langchain-core]
#    --------------------- ------------------  6/11 [langchain-core]
#    --------------------- ------------------  6/11 [langchain-core]
#    --------------------- ------------------  6/11 [langchain-core]
#    ------------------------- --------------  7/11 [langgraph-checkpoint]
#    -------------------------------- -------  9/11 [langgraph]
#    -------------------------------- -------  9/11 [langgraph]
#    -------------------------------- -------  9/11 [langgraph]
#    ------------------------------------ --- 10/11 [langchain]
#    ---------------------------------------- 11/11 [langchain]
#
# Successfully installed langchain-1.2.15 langchain-core-1.2.28 langgraph-1.1.6 langgraph-checkpoint-4.0.1 langgraph-prebuilt-1.0.9 langgraph-sdk-0.3.13 langsmith-0.7.29 orjson-3.11.8 ormsgpack-1.12.2 uuid-utils-0.14.1 xxhash-3.6.0
# Requirement already satisfied: langchain-core in c:\users\admin\anaconda3\lib\site-packages (1.2.28)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core) (0.7.29)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core) (2.12.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\admin\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\admin\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\admin\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\admin\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\admin\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.24.0)
# Requirement already satisfied: anyio in c:\users\admin\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (4.10.0)
# Requirement already satisfied: certifi in c:\users\admin\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\admin\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: idna in c:\users\admin\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\admin\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\admin\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\admin\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\admin\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\admin\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.0)

# %% [markdown]
# # Import Libraries

# %%
# Import prompt tools from LangChain

from langchain_core.prompts import PromptTemplate
from langchain_core.prompts import ChatPromptTemplate

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %% [markdown]
# # Replace Hardcoded Prompt

# %%
# Hardcoded function (not reusable)

def explain_topic_old(topic):
    return "Explain " + topic + " in simple terms for beginners"

topic = "Artificial Intelligence"

print("Input:", topic)
print("Output:", explain_topic_old(topic))
# Out:
# Input: Artificial Intelligence
# Output: Explain Artificial Intelligence in simple terms for beginners

# %%
# Using PromptTemplate instead of hardcoding

template = "Explain {topic} in simple terms for beginners"

prompt_template = PromptTemplate(
    input_variables=["topic"],
    template=template
)

topic = "Artificial Intelligence"

print("Input:", topic)

result = prompt_template.format(topic=topic)

print("Generated Prompt:", result)
# Out:
# Input: Artificial Intelligence
# Generated Prompt: Explain Artificial Intelligence in simple terms for beginners

# %% [markdown]
# # Multi Input Prompt System

# %%
# Template with multiple inputs

multi_prompt = PromptTemplate(
    input_variables=["topic","audience","tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

topic="AI"
audience="beginners"
tone="friendly"

print("Input Values")
print("Topic:",topic)
print("Audience:",audience)
print("Tone:",tone)

result = multi_prompt.format(topic=topic,audience=audience,tone=tone)

print("\nGenerated Prompt:")
print(result)
# Out:
# Input Values
# Topic: AI
# Audience: beginners
# Tone: friendly
#
# Generated Prompt:
# Explain AI for beginners in a friendly tone

# %% [markdown]
# # Prompt Variations Engine

# %%
# Creating different prompt styles

teaching_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} clearly step by step"
)

interview_template = PromptTemplate(
    input_variables=["topic"],
    template="Ask 3 questions about {topic}"
)

story_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} as a story"
)

topic="Machine Learning"

print("Input Topic:",topic)

print("\nTeaching Style Output:")
print(teaching_template.format(topic=topic))

print("\nInterview Style Output:")
print(interview_template.format(topic=topic))

print("\nStory Style Output:")
print(story_template.format(topic=topic))
# Out:
# Input Topic: Machine Learning
#
# Teaching Style Output:
# Explain Machine Learning clearly step by step
#
# Interview Style Output:
# Ask 3 questions about Machine Learning
#
# Story Style Output:
# Explain Machine Learning as a story

# %% [markdown]
# # ChatPromptTemplate System

# %%
# Chat prompt with system and user roles

chat_template = ChatPromptTemplate.from_messages([
("system","You are acting as a {role}"),
("user","Explain {topic}")
])

role="teacher"
topic="Neural Networks"

print("Input Role:",role)
print("Input Topic:",topic)

messages = chat_template.format_messages(role=role,topic=topic)

print("\nGenerated Chat Messages:")
print(messages)
# Out:
# Input Role: teacher
# Input Topic: Neural Networks
#
# Generated Chat Messages:
# [SystemMessage(content='You are acting as a teacher', additional_kwargs={}, response_metadata={}), HumanMessage(content='Explain Neural Networks', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# # Input Validation Layer

# %%
# Function to validate user inputs

def validate_inputs(audience,tone):

    valid_audience=["beginner","intermediate","expert"]
    valid_tone=["formal","casual","fun"]

    if audience not in valid_audience:
        print("Invalid audience detected → setting default = beginner")
        audience="beginner"

    if tone not in valid_tone:
        print("Invalid tone detected → setting default = formal")
        tone="formal"

    return audience,tone


audience="kids"
tone="fun"

print("Original Input:",audience,tone)

audience,tone=validate_inputs(audience,tone)

print("Validated Output:",audience,tone)
# Out:
# Original Input: kids fun
# Invalid audience detected → setting default = beginner
# Validated Output: beginner fun

# %% [markdown]
# # Prompt Generator App

# %%
generator_template = PromptTemplate(
    input_variables=["topic","audience","tone","style"],
    template="Explain {topic} for {audience} in a {tone} tone using {style} style"
)

def generate_prompt(topic,audience,tone,style):

    audience,tone=validate_inputs(audience,tone)

    prompt=generator_template.format(
        topic=topic,
        audience=audience,
        tone=tone,
        style=style
    )

    return prompt


print("Input Values")
print("Topic: Neural Networks")
print("Audience: beginner")
print("Tone: fun")
print("Style: storytelling")

result=generate_prompt("Neural Networks","beginner","fun","storytelling")

print("\nGenerated Prompt:")
print(result)
# Out:
# Input Values
# Topic: Neural Networks
# Audience: beginner
# Tone: fun
# Style: storytelling
#
# Generated Prompt:
# Explain Neural Networks for beginner in a fun tone using storytelling style

# %% [markdown]
# # Template Reusability Test

# %%
# Using one template for multiple inputs

reuse_template = PromptTemplate(
    input_variables=["topic","audience"],
    template="Explain {topic} for {audience}"
)

tests=[
("AI","students"),
("Python","beginners"),
("Deep Learning","engineers"),
("Data Science","analysts"),
("NLP","researchers")
]

print("Reusability Test\n")

for topic,audience in tests:
    print("Input:",topic,",",audience)
    print("Output:",reuse_template.format(topic=topic,audience=audience))
    print()
# Out:
# Reusability Test
#
# Input: AI , students
# Output: Explain AI for students
#
# Input: Python , beginners
# Output: Explain Python for beginners
#
# Input: Deep Learning , engineers
# Output: Explain Deep Learning for engineers
#
# Input: Data Science , analysts
# Output: Explain Data Science for analysts
#
# Input: NLP , researchers
# Output: Explain NLP for researchers
